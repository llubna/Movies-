# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
urls = ['https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=G' 
        ,'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=PG-13',
        'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=G%2FPG',
        'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=NC-17',
        'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=R',
        'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=PG',
       'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=G&offset=200',
       'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=PG&offset=200',
       'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=PG-13&offset=200',
       'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?area=XWW&by_mpaa=R&offset=200']
headers=['Title',
 'Rank',
 'Lifetime Gross',
 'Overall Rank',
 'Year']
movies = {}
counter=0

# %%
for url in urls:
    
    response = requests.get(url)
    
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    
    table = soup.find('table',class_='a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated')
    
            
            
    rows= [row for row in table.find_all('tr')]
    for row in rows[1:200]:
        items = row.find_all('td')
        link = items[0].find('a')
        title = link.text
        movies[title] = [i.text for i in items]
        counter=counter+1

# %%
headers
# Out:
# ['Title', 'Rank', 'Lifetime Gross', 'Overall Rank', 'Year']

# %%
Scraped_data = pd.DataFrame(movies).T
Scraped_data.columns=(headers)
Scraped_data.reset_index(inplace=True)
Scraped_data.drop(columns='index',inplace=True)

# %%
Scraped_data
# Out:
#                        Title Rank  Lifetime Gross Overall Rank  Year
# 0                Toy Story 4    7  $1,073,394,593           33  2019
# 1                Toy Story 3    8  $1,066,970,811           34  2010
# 2              The Lion King    1  $1,667,635,327            7  2019
# 3               Finding Nemo   19    $940,352,645           58  2003
# 4        Monsters University   36    $743,559,645          112  2013
# ...                      ...  ...             ...          ...   ...
# 1612  Office Christmas Party  395    $114,501,299        1,497  2016
# 1613               The Score  396    $114,252,154        1,499  2001
# 1614                   Saw V  397    $113,864,059        1,505  2008
# 1615                Insomnia  398    $113,758,770        1,506  2002
# 1616             Judge Dredd  399    $113,493,481        1,507  1995
#
# [1617 rows x 5 columns]

# %%
Scraped_data[Scraped_data.duplicated(keep='last')]
# Out:
# Empty DataFrame
# Columns: [Title, Rank, Lifetime Gross, Overall Rank, Year]
# Index: []

# %%
Scraped_data[Scraped_data['Title'] == 'Frozen II']
# Out:
#          Title Rank  Lifetime Gross Overall Rank  Year
# 394  Frozen II    2  $1,450,026,933           10  2019

# %%
# # remove duplicated values 
# Scraped_data=Scraped_data.drop_duplicates( keep='first', inplace=True)

# %%
## check if there is any null values
Scraped_data.isnull().sum()
# Out:
# Title             0
# Rank              0
# Lifetime Gross    0
# Overall Rank      0
# Year              0
# dtype: int64

# %%
Scraped_data["Title"] = Scraped_data.Title.str.strip().str.lower()
# Scraped_data["Year"] = Scraped_data.Year.str.strip()
# Scraped_data["Year"] = pd.to_datetime(Scraped_data["Year"])

# %%
type(Scraped_data["Year"] == '2004')
# Out:
# pandas.core.series.Series

# %%
DataSet=pd.read_csv('IMDb movies.csv')
DataSet
# Out:
# C:\Users\abdul\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       imdb_title_id                           Title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     12/26/1906
# 2                      Den sorte drøm  1911      8/19/1911
# 3                           Cleopatra  1912     11/13/1912
# 4                           L'Inferno  1911       3/6/1911
# ...                               ...   ...            ...
# 85850                         Le lion  2020      1/29/2020
# 85851  De Beentjes van Sint-Hildegard  2020      2/13/2020
# 85852       Padmavyuhathile Abhimanyu  2019       3/8/2019
# 85853               Sokagin Çocuklari  2019      3/15/2019
# 85854      La vida sense la Sara Amat  2019       2/5/2020
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#          budget  usa_gross_income worlwide_gross_income metascore  \
# 0           NaN               NaN                   NaN       NaN
# 1       $2,250                NaN                   NaN       NaN
# 2           NaN               NaN                   NaN       NaN
# 3      $45,000                NaN                   NaN       NaN
# 4           NaN               NaN                   NaN       NaN
# ...         ...               ...                   ...       ...
# 85850       NaN               NaN           $3,507,171        NaN
# 85851       NaN               NaN           $7,299,062        NaN
# 85852       NaN               NaN                   NaN       NaN
# 85853       NaN               NaN               $2,833        NaN
# 85854       NaN               NaN              $59,794        NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
DataSet.columns
# Out:
# Index(['imdb_title_id', 'Title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
# remove unwanted columns
droplist=['imdb_title_id','Title','budget','usa_gross_income','worlwide_gross_income','metascore','reviews_from_critics','reviews_from_users',
         'votes','avg_vote']
NewDataSet=DataSet
NewDataSet.drop(columns=droplist,inplace=True)

# %%
NewDataSet
# Out:
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     12/26/1906
# 2                      Den sorte drøm  1911      8/19/1911
# 3                           Cleopatra  1912     11/13/1912
# 4                           L'Inferno  1911       3/6/1911
# ...                               ...   ...            ...
# 85850                         Le lion  2020      1/29/2020
# 85851  De Beentjes van Sint-Hildegard  2020      2/13/2020
# 85852       Padmavyuhathile Abhimanyu  2019       3/8/2019
# 85853               Sokagin Çocuklari  2019      3/15/2019
# 85854      La vida sense la Sara Amat  2019       2/5/2020
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  \
# 0                          Alexander Black
# 1                             Charles Tait
# 2                                Urban Gad
# 3                       Charles L. Gaskill
# 4      Francesco Bertolini, Adolfo Padovan
# ...                                    ...
# 85850               Ludovic Colbeau-Justin
# 85851                      Johan Nijenhuis
# 85852                      Vineesh Aaradya
# 85853                    Ahmet Faik Akinci
# 85854                            Laura Jou
#
#                                       writer             production_company  \
# 0                            Alexander Black     Alexander Black Photoplays
# 1                               Charles Tait                 J. and N. Tait
# 2      Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                           Victorien Sardou  Helen Gardner Picture Players
# 4                            Dante Alighieri                    Milano Film
# ...                                      ...                            ...
# 85850  Alexandre Coquelle, Matthieu Le Naour              Monkey Pack Films
# 85851           Radek Bajgar, Herman Finkers           Johan Nijenhuis & Co
# 85852       Vineesh Aaradya, Vineesh Aaradya               RMCC Productions
# 85853         Ahmet Faik Akinci, Kasim Uçkan                    Gizem Ajans
# 85854                   Coral Cruz, Pep Puig  La Xarxa de Comunicació Local
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description
# 0      The adventures of a female reporter in the 1890s.
# 1      True story of notorious Australian outlaw Ned ...
# 2      Two men of high rank are both wooing the beaut...
# 3      The fabled queen of Egypt's affair with Roman ...
# 4      Loosely adapted from Dante's Divine Comedy and...
# ...                                                  ...
# 85850  A psychiatric hospital patient pretends to be ...
# 85851  A middle-aged veterinary surgeon believes his ...
# 85852                                                NaN
# 85853                                                NaN
# 85854  Pep, a 13-year-old boy, is in love with a girl...
#
# [85855 rows x 12 columns]

# %%
NewDataSet[NewDataSet.duplicated(keep='last')]
# Out:
# Empty DataFrame
# Columns: [original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description]
# Index: []

# %%
NewDataSet.isnull().sum()
# Out:
# original_title           0
# year                     0
# date_published           0
# genre                    0
# duration                 0
# country                 64
# language               833
# director                87
# writer                1572
# production_company    4455
# actors                  69
# description           2115
# dtype: int64

# %%
NewDataSet[NewDataSet["original_title"] == 'toy story 4']
# Out:
# Empty DataFrame
# Columns: [original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description]
# Index: []

# %%
NewDataSet["original_title"] = NewDataSet.original_title.str.strip().str.lower()

# NewDataSet["year"] = pd.to_datetime(NewDataSet["year"])
NewDataSet.isnull().sum()
# Out:
# original_title           0
# year                     0
# date_published           0
# genre                    0
# duration                 0
# country                 64
# language               833
# director                87
# writer                1572
# production_company    4455
# actors                  69
# description           2115
# dtype: int64

# %%
MergedData = pd.merge( Scraped_data,NewDataSet, left_on=['Title'], right_on = ["original_title"], how="inner")

# %%
MergedData
# Out:
#               Title Rank  Lifetime Gross Overall Rank  Year original_title  \
# 0       toy story 4    7  $1,073,394,593           33  2019    toy story 4
# 1       toy story 3    8  $1,066,970,811           34  2010    toy story 3
# 2     the lion king    1  $1,667,635,327            7  2019  the lion king
# 3     the lion king    1  $1,667,635,327            7  2019  the lion king
# 4      finding nemo   19    $940,352,645           58  2003   finding nemo
# ...             ...  ...             ...          ...   ...            ...
# 1739      the score  396    $114,252,154        1,499  2001      the score
# 1740          saw v  397    $113,864,059        1,505  2008          saw v
# 1741       insomnia  398    $113,758,770        1,506  2002       insomnia
# 1742       insomnia  398    $113,758,770        1,506  2002       insomnia
# 1743    judge dredd  399    $113,493,481        1,507  1995    judge dredd
#
#       year date_published                         genre  duration  \
# 0     2019      6/26/2019  Animation, Adventure, Comedy       100
# 1     2010       7/7/2010  Animation, Adventure, Comedy       103
# 2     1994     11/25/1994   Animation, Adventure, Drama        88
# 3     2019      8/21/2019   Animation, Adventure, Drama       118
# 4     2003      12/3/2003  Animation, Adventure, Comedy       100
# ...    ...            ...                           ...       ...
# 1739  2001     10/19/2001          Action, Crime, Drama       124
# 1740  2008      12/5/2008               Horror, Mystery        92
# 1741  1997      3/14/1997      Crime, Mystery, Thriller        96
# 1742  2002      11/8/2002      Drama, Mystery, Thriller       118
# 1743  1995      9/22/1995         Action, Crime, Sci-Fi        96
#
#                     country                               language  \
# 0                       USA                                English
# 1                       USA                       English, Spanish
# 2                       USA          English, Swahili, Xhosa, Zulu
# 3     USA, UK, South Africa  English, Xhosa, Zulu, French, Spanish
# 4            USA, Australia                                English
# ...                     ...                                    ...
# 1739   Germany, Canada, USA                        English, French
# 1740            Canada, USA                                English
# 1741                 Norway                     Norwegian, Swedish
# 1742                USA, UK                                English
# 1743                    USA                                English
#
#                          director                               writer  \
# 0                     Josh Cooley        John Lasseter, Andrew Stanton
# 1                     Lee Unkrich        John Lasseter, Andrew Stanton
# 2       Roger Allers, Rob Minkoff       Irene Mecchi, Jonathan Roberts
# 3                     Jon Favreau         Jeff Nathanson, Irene Mecchi
# 4     Andrew Stanton, Lee Unkrich       Andrew Stanton, Andrew Stanton
# ...                           ...                                  ...
# 1739                     Frank Oz        Daniel E. Taylor, Kario Salem
# 1740                  David Hackl       Patrick Melton, Marcus Dunstan
# 1741             Erik Skjoldbjærg  Nikolaj Frobenius, Erik Skjoldbjærg
# 1742            Christopher Nolan     Hillary Seitz, Nikolaj Frobenius
# 1743                 Danny Cannon         John Wagner, Carlos Ezquerra
#
#            production_company  \
# 0     Pixar Animation Studios
# 1        Walt Disney Pictures
# 2        Walt Disney Pictures
# 3        Walt Disney Pictures
# 4     Pixar Animation Studios
# ...                       ...
# 1739       Paramount Pictures
# 1740         Twisted Pictures
# 1741               Norsk Film
# 1742      Alcon Entertainment
# 1743       Hollywood Pictures
#
#                                                  actors  \
# 0     Tom Hanks, Tim Allen, Annie Potts, Tony Hale, ...
# 1     Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty,...
# 2     Rowan Atkinson, Matthew Broderick, Niketa Cala...
# 3     Chiwetel Ejiofor, John Oliver, James Earl Jone...
# 4     Albert Brooks, Ellen DeGeneres, Alexander Goul...
# ...                                                 ...
# 1739  Robert De Niro, Edward Norton, Marlon Brando, ...
# 1740  Tobin Bell, Costas Mandylor, Scott Patterson, ...
# 1741  Maria Mathiesen, Stellan Skarsgård, Sverre Ank...
# 1742  Al Pacino, Martin Donovan, Oliver 'Ole' Zemen,...
# 1743  Sylvester Stallone, Armand Assante, Rob Schnei...
#
#                                             description
# 0     When a new toy called "Forky" joins Woody and ...
# 1     The toys are mistakenly delivered to a day-car...
# 2     Lion prince Simba and his father are targeted ...
# 3     After the murder of his father, a young lion p...
# 4     After his son is captured in the Great Barrier...
# ...                                                 ...
# 1739  An aging thief hopes to retire and live off hi...
# 1740  Following Jigsaw's grisly demise, Mark Hoffman...
# 1741  In a Norwegian city with a 24-hour daylight cy...
# 1742  Two Los Angeles homicide detectives are dispat...
# 1743  In a dystopian future, Joseph Dredd, the most ...
#
# [1744 rows x 17 columns]

# %%
MergedData[MergedData.duplicated(subset=["original_title"], keep=False)].sort_values(by= "original_title")
# Out:
#                           Title Rank Lifetime Gross Overall Rank  Year  \
# 569           a christmas carol  121   $325,286,646          449  2009
# 567           a christmas carol  121   $325,286,646          449  2009
# 568           a christmas carol  121   $325,286,646          449  2009
# 1730  a nightmare on elm street  389   $115,695,182        1,478  2010
# 1731  a nightmare on elm street  389   $115,695,182        1,478  2010
# ...                         ...  ...            ...          ...   ...
# 727                      wanted   59   $342,463,063          418  2008
# 1669                       wolf  334   $131,002,597        1,311  1994
# 1668                       wolf  334   $131,002,597        1,311  1994
# 1667                       wolf  334   $131,002,597        1,311  1994
# 1666                       wolf  334   $131,002,597        1,311  1994
#
#                  original_title  year date_published  \
# 569           a christmas carol  2018     12/16/2018
# 567           a christmas carol  1938     12/16/1938
# 568           a christmas carol  2009      12/3/2009
# 1730  a nightmare on elm street  1984     11/16/1984
# 1731  a nightmare on elm street  2010      8/20/2010
# ...                         ...   ...            ...
# 727                      wanted  2010      4/30/2010
# 1669                       wolf  2019      9/13/2019
# 1668                       wolf  2013      9/19/2013
# 1667                       wolf  2012      3/11/2012
# 1666                       wolf  1994       9/3/1994
#
#                          genre  duration      country  \
# 569                    Fantasy        75          USA
# 567     Drama, Family, Fantasy        69          USA
# 568   Animation, Drama, Family        96          USA
# 1730                    Horror        91          USA
# 1731      Crime, Drama, Horror        95          USA
# ...                        ...       ...          ...
# 727                     Action       110        India
# 1669                     Drama        85           UK
# 1668    Crime, Drama, Thriller       122  Netherlands
# 1667             Drama, Family        87          USA
# 1666    Drama, Horror, Romance       125          USA
#
#                                      language         director  \
# 569                                   English      David Izatt
# 567                                   English   Edwin L. Marin
# 568                                   English  Robert Zemeckis
# 1730                                  English       Wes Craven
# 1731                                  English     Samuel Bayer
# ...                                       ...              ...
# 727                                   Bengali      Rabi Kinagi
# 1669                                  English   Stuart Brennan
# 1668  Dutch, Arabic, French, Turkish, English     Jim Taihuttu
# 1667                                  English      Ya'Ke Smith
# 1666                         English, Spanish     Mike Nichols
#
#                                 writer         production_company  \
# 569                     Stuart Brennan                  Towerflix
# 567       Charles Dickens, Hugo Butler  Metro-Goldwyn-Mayer (MGM)
# 568   Charles Dickens, Robert Zemeckis       Walt Disney Pictures
# 1730                        Wes Craven            New Line Cinema
# 1731     Wesley Strick, Eric Heisserer            New Line Cinema
# ...                                ...                        ...
# 727     Paulami Bhowmick, Ananyo Mamun               Eskay Movies
# 1669  Stuart Brennan, George McCluskey                 Stronghold
# 1668                      Jim Taihuttu                 Habbekrats
# 1667                       Ya'Ke Smith      Aristar Entertainment
# 1666       Jim Harrison, Wesley Strick          Columbia Pictures
#
#                                                  actors  \
# 569   Bonnie Wright, Rebecca Hanssen, Stuart Brennan...
# 567   Reginald Owen, Gene Lockhart, Kathleen Lockhar...
# 568   Jim Carrey, Steve Valentine, Daryl Sabara, Sag...
# 1730  John Saxon, Ronee Blakley, Heather Langenkamp,...
# 1731  Jackie Earle Haley, Kyle Gallner, Rooney Mara,...
# ...                                                 ...
# 727   Jeet, Srabanti Chatterjee, Indrajit, Biswajit ...
# 1669  Stuart Brennan, Mark Paul Wake, George McClusk...
# 1668  Marwan Kenzari, Chems Eddine Amar, Steef Cuijp...
# 1667  Selena Aguilar, Pedro Castaneda, Jordan Cooper...
# 1666  Jack Nicholson, Michelle Pfeiffer, James Spade...
#
#                                             description
# 569   A contemporary retelling of the timeless Dicke...
# 567   On Christmas Eve, Ebenezer Scrooge is visited ...
# 568   An animated retelling of Charles Dickens' clas...
# 1730  The monstrous spirit of a slain child murderer...
# 1731  The spectre of a disfigured man haunts the chi...
# ...                                                 ...
# 727   Jeet was hired to shoot someone,but not kill.B...
# 1669  When four messengers sent by Rome to a plague ...
# 1668  A promising kickboxer struggles to resist the ...
# 1667  A family is shaken to the core when they disco...
# 1666  Publisher Will Randall becomes a werewolf and ...
#
# [579 rows x 17 columns]
