# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np 
import csv

# %%
df=pd.read_csv('IMDb movies.csv')
df2=pd.read_csv('movies.csv')
# Out:
# C:\Users\abdul\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'Title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df=df.rename(columns={'title':'Title'})

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'Title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Rank', 'Lifetime Gross', 'Overall Rank',
#        'Year'],
#       dtype='object')

# %%
droplist=['imdb_title_id','budget','usa_gross_income','worlwide_gross_income','metascore']

# %%
newdf=df
newdf=df.drop(columns=droplist,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-d3d346c1235b> in <module>
#       1 newdf=df
# ----> 2 newdf=df.drop(columns=droplist,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
newdf.head()
# Out:
#                          Title               original_title  year  \
# 0                   Miss Jerry                   Miss Jerry  1894
# 1  The Story of the Kelly Gang  The Story of the Kelly Gang  1906
# 2               Den sorte drøm               Den sorte drøm  1911
# 3                    Cleopatra                    Cleopatra  1912
# 4                    L'Inferno                    L'Inferno  1911
#
#   date_published                      genre  duration           country  \
# 0     1894-10-09                    Romance        45               USA
# 1     12/26/1906    Biography, Crime, Drama        70         Australia
# 2      8/19/1911                      Drama        53  Germany, Denmark
# 3     11/13/1912             Drama, History       100               USA
# 4       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# 0     None                      Alexander Black
# ...

# %%
df["original_title"] = df.original_title.str.strip().str.lower()

# %%
df2["Title"] = df2.Title.str.strip().str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-3ef604c8bc4e> in <module>
# ----> 1 df2["original_title"] = df2.original_title.str.strip().str.lower()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'original_title'

# %%
df.Title.unique()
# Out:
# array(['Miss Jerry', 'The Story of the Kelly Gang', 'Den sorte drøm', ...,
#        'Padmavyuhathile Abhimanyu', 'Sokagin Çocuklari',
#        'La vida sense la Sara Amat'], dtype=object)

# %%
df2.Title.unique()
# Out:
# array(['Toy Story 4', 'Toy Story 3', 'The Lion King', 'Finding Nemo',
#        'Monsters University', 'Ratatouille', 'Monsters, Inc.', 'Cars 2',
#        'WALL·E', 'Aladdin', 'Rio 2', 'Toy Story 2', 'Cars', 'Tarzan',
#        'Beauty and the Beast', 'Gone with the Wind', 'Toy Story',
#        'Cars 3', "A Bug's Life", 'Pocahontas',
#        'Alvin and the Chipmunks: Chipwrecked',
#        'The Hunchback of Notre Dame', '101 Dalmatians', 'Chicken Little',
#        'The Polar Express', 'Mulan', 'Horton Hears a Who!', 'Bambi',
#        'The Princess and the Frog', 'Babe',
#        'High School Musical 3: Senior Year', 'Hercules', 'Brother Bear',
#        'The Peanuts Movie', "Mr. Bean's Holiday", 'Chicken Run',
#        'One Hundred and One Dalmatians', 'The Little Mermaid',
#        'The Jungle Book', 'Ponyo',
#        'Wallace & Gromit: The Curse of the Were-Rabbit',
#        'Gnomeo & Juliet', 'The Jungle Book 2',
#        'Snow White and the Seven Dwarfs', '102 Dalmatians',
# ...

# %%
df.Title[0]
# Out:
# 'Miss Jerry'

# %%
df2.Title[0]
# Out:
# 'Toy Story 4'

# %%
df = df.Title.strip()
df
# Out:
# 0                            Toy Story 4
# 1                            Toy Story 3
# 2                          The Lion King
# 3                           Finding Nemo
# 4                    Monsters University
#                      ...
# 194                    The Corsican File
# 195       Beneath the Planet of the Apes
# 196      Thrill Ride: The Science of Fun
# 197    Peppa Celebrates Chinese New Year
# 198                              Prancer
# Name: Title, Length: 199, dtype: object

# %%
df[df.Title.str.contains("toy")]
# Out:
#                                                Title  \
# 5949                povest o nastoyashchem cheloveke
# 10602                               babes in toyland
# 13827                               zolotoy telyonok
# 14920                          dostoyanie respubliki
# 16503                                     peopletoys
# 17093                                   laura's toys
# 17949                          estoy hecho un chaval
# 18140                    po semeynym obstoyatelstvam
# 21732                                   toy soldiers
# 24739                              the magic toyshop
# 24776                            montoyas y tarantos
# 26876                         samostoyatelnaya zhizn
# 26967                              toys - giocattoli
# 29371            toy story - il mondo dei giocattoli
# 30867                                nettoyage à sec
# 31096       toy story 2 - woody & buzz alla riscossa
# 32468                                v toy strane...
# ...

# %%
df.original_title.nunique()
# Out:
# 80800

# %%
df.original_title.count()
# Out:
# 85855

# %%
df[df.duplicated(subset=["original_title"], keep=False)].sort_values(by= "original_title")
# Out:
#             Title original_title  year date_published  \
# 45469           1              1  2009      11/5/2009
# 66998    plus one              1  2013     10/24/2013
# 62805   100% love      100% love  2011       5/6/2011
# 67915   100% love      100% love  2012      1/20/2012
# 85781      15-aug         15-aug  2019      3/29/2019
# ...           ...            ...   ...            ...
# 35709      zvezda         zvezda  1953      9/21/1953
# 73195      zvezda         zvezda  2014      12/4/2014
# 42162      zvezda         zvezda  2002       5/6/2002
# 39839  üç arkadas     üç arkadas  1958           1958
# 40018  üç arkadas     üç arkadas  1972       2/1/1972
#
#                            genre  duration       country  \
# 45469           Sci-Fi, Thriller        91       Hungary
# 66998  Romance, Sci-Fi, Thriller        96           USA
# 62805     Comedy, Drama, Romance       141         India
# 67915     Comedy, Drama, Romance       166         India
# ...

# %%
aa = pd.merge(df2, df, left_on='Title', right_on = "original_title", how="left")
aa.count()
# Out:
# Unnamed: 0              250
# Title_x                 250
# Rank                    250
# Lifetime Gross          250
# Overall Rank            250
# Year                    250
# Title_y                 196
# original_title          196
# year                    196
# date_published          196
# genre                   196
# duration                196
# country                 196
# language                192
# director                196
# writer                  195
# production_company      195
# actors                  196
# description             196
# avg_vote                196
# votes                   196
# reviews_from_users      195
# reviews_from_critics    194
# dtype: int64

# %%
df_merge_col
# Out:
# Empty DataFrame
# Columns: [Title, original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description, avg_vote, votes, reviews_from_users, reviews_from_critics, Unnamed: 0, Rank, Lifetime Gross, Overall Rank, Year]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.merge(df2,how='inner',on='Title')
# Out:
# Empty DataFrame
# Columns: [Title, original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description, avg_vote, votes, reviews_from_users, reviews_from_critics, Unnamed: 0, Rank, Lifetime Gross, Overall Rank, Year]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Title', 'original_title', 'year', 'date_published', 'genre',
#        'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')
